# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaikSalmanBasha948/shaik-salman/blob/main/StringAssignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# text = "Edukron Data Science and Data Engineering Batch 2026"

# %%
text = "Edukron Data Science and Data Engineering Batch 2026"

# %% [markdown]
# 1.Write the indexing expression to print *"Edukron"*.

# %%
text[0:8]
text[-52:-45]
# Out:
# 'Edukron'

# %% [markdown]
# 2.Write the indexing expression to print *"Data"* (first occurrence).

# %%
text[8:12]
text[-27:-23]
# Out:
# 'Data'

# %% [markdown]
# 3.Write the indexing expression to print *"Science"*

# %%
text[13:20]
text[-39:-32]

# %% [markdown]
# 4.Write the indexing expression to print *"and"*

# %%
text[21:24]
text[-31:-28]
# Out:
# 'and'

# %% [markdown]
# 5.Write the indexing expression to print *"Data Engineering"*

# %%
text[25:41]
text[-27:-10]
# Out:
# 'Data Engineering '

# %% [markdown]
# 6.Write the indexing expression to print *"Engineering"*

# %%
text[30:41]
text[-22:-11]
# Out:
# 'Engineering'

# %% [markdown]
# 7.Write the indexing expression to print *"Batch"*.

# %%
text[42:47]
text[-10:-4]
# Out:
# 'Batch '

# %% [markdown]
# 8.Write the indexing expression to print *"2026"*.

# %%
text[48:52]
text[-4:52]
# Out:
# '2026'

# %% [markdown]
# 9.9. Write the indexing expression to print *"Science and Data"*.

# %%
text[13:29]
# Out:
# 'Science and Data'

# %% [markdown]
# 10.Write the indexing expression to print *"Data Science and Data Engineering Batch"*.

# %%
text[8:47]
text[-44:-4]
# Out:
# 'Data Science and Data Engineering Batch '
